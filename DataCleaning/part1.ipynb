# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("row.csv")
dataset.head(6)
# Out:
#    ID    Name  Age  Gender       City  Salary Married Education  Experience  \
# 0   1  User_1   56    Male      Delhi   67926     Yes  Graduate         2.2
# 1   2  User_2   69  Female  Bangalore   49189      No  Graduate         6.0
# 2   3  User_3   46  Female      Delhi   32763      No  Graduate         2.9
# 3   4  User_4   32  Female      Delhi   38384      No  Graduate         7.6
# 4   5  User_5   60    Male     Mumbai   80100      No  Graduate         4.5
# 5   6  User_6   25    Male      Delhi  118142     Yes  Graduate         5.3
#
#   Purchased  ...  Subscription  Country   Mobile_No Account_Balance  \
# 0        No  ...       Premium      NaN  9999770487         9771.50
# 1        No  ...          Free       UK  9999216739         6175.04
# 2        No  ...       Premium      USA  9999126225        20143.14
# 3       Yes  ...         Basic      NaN  9999877572        14792.38
# 4        No  ...           NaN    India  9999388389         4517.99
# ...

# %%
dataset.shape
(dataset.isnull().sum())/dataset.shape[0]*100
# Out:
# ID                   0.000000
# Name                 0.000000
# Age                  0.000000
# Gender               7.317073
# City                 0.000000
# Salary               0.000000
# Married              2.926829
# Education            2.926829
# Experience           0.000000
# Purchased            0.000000
# Rating               4.878049
# Login_Count          0.000000
# Feedback_Score       0.000000
# Subscription         5.853659
# Country             18.048780
# Mobile_No            0.000000
# Account_Balance      0.000000
# Loan_Status         31.219512
# Product_Category    18.048780
# Is_Active            0.000000
# Join_Date            0.000000
# Email_Verified       0.000000
# Referral_Code        8.780488
# dtype: float64

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(205)

# %%
dataset.notnull().sum()
# Out:
# ID                  205
# Name                205
# Age                 205
# Gender              190
# City                205
# Salary              205
# Married             199
# Education           199
# Experience          205
# Purchased           205
# Rating              195
# Login_Count         205
# Feedback_Score      205
# Subscription        193
# Country             168
# Mobile_No           205
# Account_Balance     205
# Loan_Status         141
# Product_Category    168
# Is_Active           205
# Join_Date           205
# Email_Verified      205
# Referral_Code       187
# dtype: int64

# %%
sns.heatmap(dataset.isnull()) 
plt.show()
