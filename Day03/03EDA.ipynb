# %% [markdown]
# ### EDA using Bivariate and Multivarient  Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
titanic = pd.read_csv('train_sample.csv')
flights = sns.load_dataset('flights')
iris = pd.read_csv("iris_dataset.csv")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %% [markdown]
# ## 1. Scatterplot ( Numerical - Numerical )

# %%
# Bivarint analys sns.scatterplot(x=tips['total_bill'],y=tips['tip'])
sns.scatterplot(x=tips['total_bill'] , y=tips['tip'] , hue=tips['sex'] , style=tips['smoker'], size= tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 2. Bar Plot ( Numerical - Categorical )

# %%
sns.barplot(x=titanic['Pclass'] , y=titanic['Fare'] , hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## 3. Box Plot (Numerical - Categorical )

# %%
sns.boxenplot(x=titanic['Sex'] , y=titanic['Age'] ,hue = titanic['Survived'] )
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## 4. Distplot ( Numerical - Categrorical)

# %%
sns.displot(data=titanic, x="Age", hue="Survived", kind="kde")

# %% [markdown]
# ## 5. HeatMap ( Categorical - Categorical)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'] , titanic['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#(titanic.groupby('Embarked').mean()['Survived'] * 100)

# %% [markdown]
# ## 6. ClusterMap ( Categrorical - Categorical )

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'] , titanic['Survived']))

# %% [markdown]
# ## 7. Pairplot

# %%
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
sns.pairplot(iris, hue="target")

# %% [markdown]
# ## 8. Lineplot (Numerical - Numerical) // X-xex time based

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.groupby('year').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 flights.groupby('year').sum()
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:3152, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    3147 else:
#    3148     # If we are grouping on categoricals we want unobserved categories to
#    3149     # return zero, rather than the default of NaN which the reindexing in
#    3150     # _agg_general() returns. GH #31422
#    3151     with com.temp_setattr(self, "observed", True):
# -> 3152         result = self._agg_general(
#    3153             numeric_only=numeric_only,
#    3154             min_count=min_count,
#    3155             alias="sum",
#    3156             npfunc=np.sum,
#    3157         )
#    3159     return self._reindex_output(result, fill_value=0)
#
# ...
