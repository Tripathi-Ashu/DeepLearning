# %%
import pandas as pd

# %%
df = pd.read_csv('train_sample.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (1.16.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (2.3.1)
# Requirement already satisfied: matplotlib>=3.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (3.10.3)
# Collecting pydantic>=1.8.1 (from pandas-profiling)
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Requirement already satisfied: PyYAML>=5.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (2.3.1)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (2.32.4)
# Collecting tqdm>=4.48.2 (from pandas-profiling)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: seaborn>=0.10.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: attrs>=19.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /home/codespace/.local/lib/python3.12/site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.3)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.12/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2025.2)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.8.1->pandas-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=1.8.1->pandas-profiling)
#   Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling) (4.14.1)
# Collecting typing-inspection>=0.4.0 (from pydantic>=1.8.1->pandas-profiling)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling) (2025.7.9)
# Collecting PyWavelets (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading pywavelets-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.6 kB)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 17.5 MB/s eta 0:00:0000:01
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading phik-0.12.5-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 28.0 MB/s eta 0:00:00
# Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 41.1 MB/s eta 0:00:00
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading pywavelets-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 34.0 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (pyproject.toml) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27161 sha256=2f99eb1bd446fcb4d9cc7e36025d2347a8e8684c0243fc74fa10cb0f761bc268
#   Stored in directory: /home/codespace/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: htmlmin, typing-inspection, tqdm, tangled-up-in-unicode, PyWavelets, pydantic-core, multimethod, markupsafe, joblib, annotated-types, pydantic, imagehash, visions, phik, missingno, pandas-profiling
#   Attempting uninstall: markupsafe90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [PyWavelets]in-unicode]
#     Found existing installation: MarkupSafe 3.0.2━━━━━━━━━━━━━  4/16 [PyWavelets]
#     Uninstalling MarkupSafe-3.0.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [PyWavelets]
#       Successfully uninstalled MarkupSafe-3.0.2━━━━━━━━━━━━━━━  4/16 [PyWavelets]
#   Attempting uninstall: joblib90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [PyWavelets]
#     Found existing installation: joblib 1.5.1━━━━━━━━━━━━━━━━━  4/16 [PyWavelets]
#     Uninstalling joblib-1.5.1:90m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/16 [PyWavelets]
#       Successfully uninstalled joblib-1.5.1━━━━━━━━━━━━━━━━━━━  8/16 [joblib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [pandas-profiling][pandas-profiling]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.7.0 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# Successfully installed PyWavelets-1.9.0 annotated-types-0.7.0 htmlmin-0.1.12 imagehash-4.3.2 joblib-1.1.1 markupsafe-2.1.5 missingno-0.5.2 multimethod-2.0 pandas-profiling-3.2.0 phik-0.12.5 pydantic-2.11.9 pydantic-core-2.33.2 tangled-up-in-unicode-0.2.0 tqdm-4.67.1 typing-inspection-0.4.1 visions-0.7.4
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
pip install --upgrade ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in /usr/local/python/3.12.1/lib/python3.12/site-packages (4.16.1)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in /home/codespace/.local/lib/python3.12/site-packages (from ydata-profiling) (2.3.1)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic>=2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (2.11.9)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /home/codespace/.local/lib/python3.12/site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling)
#   Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: htmlmin==0.1.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/codespace/.local/lib/python3.12/site-packages (from ydata-profiling) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /home/codespace/.local/lib/python3.12/site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (4.4.4)
# Requirement already satisfied: imagehash==4.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<=0.61,>=0.56.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from ydata-profiling) (0.61.0)
# Requirement already satisfied: PyWavelets in /usr/local/python/3.12.1/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in /home/codespace/.local/lib/python3.12/site-packages (from imagehash==4.3.1->ydata-profiling) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from numba<=0.61,>=0.56.0->ydata-profiling) (0.44.0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.7.9)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: typing_extensions>=4.14.0 in /home/codespace/.local/lib/python3.12/site-packages (from typeguard<5,>=3->ydata-profiling) (4.14.1)
# Requirement already satisfied: attrs>=19.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /home/codespace/.local/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.3)
# Requirement already satisfied: puremagic in /usr/local/python/3.12.1/lib/python3.12/site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (1.30)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)
# Using cached numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.3
#     Uninstalling numpy-2.3.3:
#       Successfully uninstalled numpy-2.3.3
#   WARNING: The scripts f2py and numpy-config are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.7.0 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
# Successfully installed numpy-2.1.3
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas-profiling==3.2.0
# Out:
# Requirement already satisfied: pandas-profiling==3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (1.15.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (2.3.1)
# Requirement already satisfied: matplotlib>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (3.10.0)
# Requirement already satisfied: pydantic>=1.8.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (2.11.9)
# Requirement already satisfied: PyYAML>=5.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (3.1.6)
# Requirement already satisfied: markupsafe~=2.1.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (2.1.5)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling==3.2.0)
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (2.1.3)
# Requirement already satisfied: htmlmin>=0.1.12 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (0.12.5)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.48.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (4.67.1)
# Requirement already satisfied: seaborn>=0.10.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pandas-profiling==3.2.0) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling==3.2.0) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in /home/codespace/.local/lib/python3.12/site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling==3.2.0) (3.3)
# Requirement already satisfied: imagehash in /usr/local/python/3.12.1/lib/python3.12/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.2.0) (4.3.1)
# Requirement already satisfied: Pillow in /home/codespace/.local/lib/python3.12/site-packages (from visions[type_image_path]==0.7.4->pandas-profiling==3.2.0) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib>=3.2.0->pandas-profiling==3.2.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.2.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling==3.2.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling==3.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling==3.2.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling==3.2.0) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic>=1.8.1->pandas-profiling==3.2.0) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling==3.2.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling==3.2.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling==3.2.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling==3.2.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.24.0->pandas-profiling==3.2.0) (2025.7.9)
# Requirement already satisfied: PyWavelets in /usr/local/python/3.12.1/lib/python3.12/site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling==3.2.0) (1.9.0)
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Installing collected packages: visions
#   Attempting uninstall: visions
#     Found existing installation: visions 0.8.1
#     Uninstalling visions-0.8.1:
#       Successfully uninstalled visions-0.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires visions[type_image_path]<0.8.2,>=0.7.5, but you have visions 0.7.4 which is incompatible.
# Successfully installed visions-0.7.4
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas_profiling/__init__.py:8
#       5 import importlib.util
#       6 from warnings import warn
# ----> 8 from ydata_profiling.compare_reports import compare
#       9 from ydata_profiling.controller import pandas_decorator
#      10 from ydata_profiling.profile_report import ProfileReport
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/profile_report.py:32
#      30 from ydata_profiling.model import BaseDescription
#      31 from ydata_profiling.model.alerts import AlertType
# ---> 32 from ydata_profiling.model.describe import describe as describe_df
#      33 from ydata_profiling.model.sample import Sample
#      34 from ydata_profiling.model.summarizer import (
#      35     BaseSummarizer,
#      36     ProfilingSummarizer,
#      37     format_summary,
#      38     redact_summary,
#      39 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/model/describe.py:16
#      11 from ydata_profiling.model.alerts import get_alerts
#      12 from ydata_profiling.model.correlations import (
#      13     calculate_correlation,
#      14     get_active_correlations,
#      15 )
# ---> 16 from ydata_profiling.model.dataframe import preprocess
#      17 from ydata_profiling.model.description import TimeIndexAnalysis
#      18 from ydata_profiling.model.duplicates import get_duplicates
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/model/dataframe.py:7
#       4 import pandas as pd
#       6 from ydata_profiling.config import Settings
# ----> 7 from ydata_profiling.model.pandas.dataframe_pandas import pandas_preprocess
#       9 spec = importlib.util.find_spec("pyspark")
#      10 if spec is None:
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/model/pandas/__init__.py:27
#      25 # Dynamically import and expose functions from modules
#      26 for module_name in PANDAS_MODULES:
# ---> 27     module = importlib.import_module(f"ydata_profiling.model.pandas.{module_name}")
#      28     globals().update(
#      29         {
#      30             name: getattr(module, name)
#    (...)     33         }
#      34     )
#      36 # Explicitly list exposed names for clarity
#
# File /usr/local/python/3.12.1/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/model/pandas/correlations_pandas.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from scipy import stats
#      10 from ydata_profiling.config import Settings
#      11 from ydata_profiling.model.pandas.discretize_pandas import (
#      12     DiscretizationType,
#      13     Discretizer,
#      14 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File /usr/local/python/3.12.1/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/stats/__init__.py:624
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    619
#     620 """  # noqa: E501
#     622 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     623                                DegenerateDataWarning, FitError)
# --> 624 from ._stats_py import *
#     625 from ._variation import variation
#     626 from .distributions import *
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/stats/_stats_py.py:38
#      35 import numpy as np
#      36 from numpy import array, asarray, ma
# ---> 38 from scipy import sparse
#      39 from scipy.spatial import distance_matrix
#      41 from scipy.optimize import milp, LinearConstraint
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File /usr/local/python/3.12.1/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/sparse/__init__.py:300
#     294 # Original code by Travis Oliphant.
#     295 # Modified and extended by Ed Schofield, Robert Cimrman,
#     296 # Nathan Bell, and Jake Vanderplas.
#     298 import warnings as _warnings
# --> 300 from ._base import *
#     301 from ._csr import *
#     302 from ._csc import *
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/sparse/_base.py:5
#       1 """Base class for sparse matrices"""
#       3 import numpy as np
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#       7                        matrix, validateaxis, getdtype)
#       9 from ._matrix import spmatrix
#      11 __all__ = ['isspmatrix', 'issparse', 'sparray',
#      12            'SparseWarning', 'SparseEfficiencyWarning']
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/sparse/_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/_lib/_util.py:13
#      10 from typing import TypeAlias, TypeVar
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#      17 AxisError: type[Exception]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/scipy/_lib/_array_api.py:15
#      12 from typing import Any, Literal, TypeAlias
#      14 import numpy as np
# ---> 15 import numpy.typing as npt
#      17 from scipy._lib import array_api_compat
#      18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#      20     size as xp_size,
#    (...)     27     is_array_api_strict_namespace as is_array_api_strict
#      28 )
#
# ModuleNotFoundError: No module named 'numpy.typing'
