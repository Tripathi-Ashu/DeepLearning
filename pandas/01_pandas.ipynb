# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data_sample.csv" , encoding="latin1")

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 35],
    "City": ["New York", "Los Angeles", "Chicago"]      
}

df2 = pd.DataFrame(data) 
df2
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %%
df2.to_excel("data.xlsx", index=False)  # ✅ Correct for Excel

# %%
# !pip install openpyxl

# %%
df2.to_csv("data.csv")

# %%
df.to_excel("sales_data.xlsx", index=False)  # ✅ Correct for Excel

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   City    3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
data2 = {
    "Name": ["David", "Emma", "Frank", "Grace", "Helen", "Ian", "Julia", "Kevin", "Laura", "Mike"],
    "Age": [28, 32, 40, 26, 29, 34, 31, 38, 27, 36],
    "Salary": [55000, 72000, 68000, 48000, 60000, 75000, 71000, 67000, 53000, 80000],
    "Performance_Score": [88, 92, 85, 90, 87, 93, 89, 86, 91, 94]
}

df2 = pd.DataFrame(data2)
df2.describe()
# Out:
#              Age       Salary  Performance_Score
# count  10.000000     10.00000           10.00000
# mean   32.100000  64900.00000           89.50000
# std     4.794673  10439.77437            3.02765
# min    26.000000  48000.00000           85.00000
# 25%    28.250000  56250.00000           87.25000
# 50%    31.500000  67500.00000           89.50000
# 75%    35.500000  71750.00000           91.75000
# max    40.000000  80000.00000           94.00000

# %%
df2.shape
df2.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'Performance Score'], dtype='object')

# %%
df2["Age"]
df2[["Age", "Name"]]
# Out:
#    Age   Name
# 0   28  David
# 1   32   Emma
# 2   40  Frank
# 3   26  Grace
# 4   29  Helen
# 5   34    Ian
# 6   31  Julia
# 7   38  Kevin
# 8   27  Laura
# 9   36   Mike

# %%
df2[df2["Age"] > 30]
# Out:
#     Name  Age  Salary  Performance Score
# 1   Emma   32   72000                 92
# 2  Frank   40   68000                 85
# 5    Ian   34   75000                 93
# 6  Julia   31   71000                 89
# 7  Kevin   38   67000                 86
# 9   Mike   36   80000                 94

# %%
df2[df2["Age"] > 30][["Name", "Age"]]
df2[df2["Age"] > 30].sort_values(by="Age", ascending=False) 
df2[df2["Age"] < 35].sort_values(by="Salary")[["Name", "Salary"]]
# Out:
#     Name  Salary
# 3  Grace   48000
# 8  Laura   53000
# 0  David   55000
# 4  Helen   60000
# 6  Julia   71000
# 1   Emma   72000
# 5    Ian   75000

# %%
df2[(df2["Age"] > 30 ) & (df2["Salary"] > 55000)]
# Out:
#     Name  Age  Salary  Performance Score
# 1   Emma   32   72000                 92
# 2  Frank   40   68000                 85
# 5    Ian   34   75000                 93
# 6  Julia   31   71000                 89
# 7  Kevin   38   67000                 86
# 9   Mike   36   80000                 94

# %%
df2[(df2["Age"] > 30) | (df2["Performance_Score"] > 90)] # This will raise an error
# Out:
#     Name  Age  Salary  Performance_Score
# 1   Emma   32   72000                 92
# 2  Frank   40   68000                 85
# 5    Ian   34   75000                 93
# 6  Julia   31   71000                 89
# 7  Kevin   38   67000                 86
# 8  Laura   27   53000                 91
# 9   Mike   36   80000                 94
